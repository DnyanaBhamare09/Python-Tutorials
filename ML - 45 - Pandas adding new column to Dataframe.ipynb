# %%
import pandas as pd

nba = pd.read_csv("nba.csv")

# %%
nba["Name"]
# nba ["League"]     # It gives error coz League column is not there so we add it as
nba ["League"] = "Basketball"
nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary      League
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
nba["Match"] = "National Event"
nba.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary      League           Match
# 0              Texas  7730337.0  Basketball  National Event
# 1          Marquette  6796117.0  Basketball  National Event
# 2  Boston University        NaN  Basketball  National Event
# 3      Georgia State  1148640.0  Basketball  National Event
# 4                NaN  5000000.0  Basketball  National Event

# %%
# We add new column to spcific location by using insert
import pandas as pd

nba1 = pd.read_csv("nba.csv")

# %%
nba1.insert(4, column = "Sport", value = "Basketball")
nba1.head()
# Out:
#             Name            Team  Number Position       Sport  Age  Height  \
# 0  Avery Bradley  Boston Celtics       0       PG  Basketball   25   2-Jun
# 1    Jae Crowder  Boston Celtics      99       SF  Basketball   25   6-Jun
# 2   John Holland  Boston Celtics      30       SG  Basketball   27   5-Jun
# 3    R.J. Hunter  Boston Celtics      28       SG  Basketball   22   5-Jun
# 4  Jonas Jerebko  Boston Celtics       8       PF  Basketball   29  10-Jun
#
#    Weight            College     Salary
# 0     180              Texas  7730337.0
# 1     235          Marquette  6796117.0
# 2     205  Boston University        NaN
# 3     185      Georgia State  1148640.0
# 4     231                NaN  5000000.0
